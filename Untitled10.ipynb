# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a201-hue/python-record/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
input_str = input("Enter a string: ")
if input_str == input_str[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
for ch in set(input_str):
    print(ch)
    count = input_str.count(ch)
    print(f"'{ch}' appears {count} times")
# Out:
# Enter a string: asritha
# Not Palindrome
# t
# 't' appears 1 times
# s
# 's' appears 1 times
# i
# 'i' appears 1 times
# a
# 'a' appears 2 times
# r
# 'r' appears 1 times
# h
# 'h' appears 1 times
